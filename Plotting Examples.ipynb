# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta
from IPython.core.display import display, HTML
import os
import sys
import urllib

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Set default cell width
display(HTML('<style>.container {width:80% !important;}</style>'))

# Set default matplotlib settings
plt.rcParams['figure.figsize'] = (10, 8)
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['figure.titlesize'] = 26
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['axes.titlesize'] = 22
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14
plt.rcParams['legend.fontsize'] = 16
# Out:
# <style>.container {width:80% !important;}</style>

# %% [markdown]
# # Examples
# ## Setting Seaborn Colours
# Since seaborn uses different colours, we can set them ahead of time to use when plotting

# %%
sns.palplot(sns.color_palette())
blue, green, red, purple, yellow, cyan = sns.color_palette('deep')

# %%
plt.plot(np.arange(10), np.arange(10), c=red, linewidth=4)
plt.tight_layout()

# %% [markdown]
# We may also change the colour palette.

# %%
sns.palplot(sns.color_palette('Blues'))

# %%
sns.set_palette('Blues')
plt.title('Demonstration of Different Colour Palettes in Seaborn')
for i in range(6):
    plt.plot(np.linspace(i, i+0.5, 5), np.arange(5), linewidth=10)
plt.tight_layout()

# %% [markdown]
# ## Plotting
# We can now reset the palette to the default 'deep'.

# %%
sns.set_palette('deep')

# %%
df = pd.DataFrame({'x': np.arange(-10, 10.1, 0.1)})
df['y'] = df.x**2

plt.plot(df.x, df.y, label='parabola')
plt.title('Title')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.legend(loc=0)  # 0 is best location
plt.tight_layout()

# %% [markdown]
# ## Multiple Plots

# %%
df = pd.DataFrame({'x': np.arange(-10, 10.1, 0.5)})
df['y0'] = np.sqrt(np.abs(df.x))
df['y1'] = df.x
df['y2'] = df.x**2
df['y3'] = np.abs(df.x)

plt.suptitle('Multiple Plots', fontsize=24)
# Adjusts spacing between plots
plt.subplots_adjust(wspace=0.3, hspace=0.3)

plt.subplot(221)
plt.plot(df.x, df.y0)
plt.title('Square Root')

plt.subplot(222)
plt.plot(df.x, df.y1)
plt.title('Linear')

plt.subplot(223)
plt.plot(df.x, df.y2)
plt.title('Quadratic')

plt.subplot(224)
plt.plot(df.x, df.y3)
plt.title('Absolute Value')

# %%
f, ax = plt.subplots(nrows=2, ncols=2)
plt.suptitle('Multiple Plots')
# Adjusts spacing between plots
plt.subplots_adjust(wspace=0.3, hspace=0.3)

ax[0, 0].plot(df.x, df.y0)
ax[0, 0].set_title('Square Root')

ax[0, 1].plot(df.x, df.y1)
ax[0, 1].set_title('Linear')

ax[1, 0].plot(df.x, df.y2)
ax[1, 0].set_title('Quadratic')

ax[1, 1].plot(df.x, df.y3)
ax[1, 1].set_title('Absolute Value')

# %% [markdown]
# ## Adding Axes on the Right

# %%
plt.title('Overlaid Plots with Different Scales')

ax0 = plt.subplot()
ax0.plot(df.x, df.y2)
for tl in ax0.get_yticklabels():
    tl.set_color(blue)

ax1 = ax0.twinx()
ax1.plot(df.x, df.y0, c=red)
for tl in ax1.get_yticklabels():
    tl.set_color(red)
